# %%
import pandas as pd
import numpy as np
import seaborn as sns

# 한글폰트 사용을 위해 설치
# 아래 모듈을 설치하고 불러오면 별도의 한글폰트 설정이 필요 없습니다.
# colab 에서도 아래 설치 문구의 주석을 제거하고 설치하고 import 해주기만 하면 한글폰트가 잘 나옵니다.
# !pip install koreanize-matplotlib

import koreanize_matplotlib

# df = pd.read_csv("boostcourse-ds-510/data/NHIS_OPEN_GJ_2017.CSV.zip", encoding="cp949")
df = pd.read_csv("https://raw.githubusercontent.com/corazzon/boostcourse-ds-510/master/data/NHIS_OPEN_GJ_2017.CSV.zip",
                 encoding="cp949")
# Out:
# [notice] A new release of pip is available: 23.2.1 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: koreanize-matplotlib in c:\users\11win\anaconda3\lib\site-packages (0.1.1)
# Requirement already satisfied: matplotlib in c:\users\11win\anaconda3\lib\site-packages (from koreanize-matplotlib) (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\11win\anaconda3\lib\site-packages (from matplotlib->koreanize-matplotlib) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\11win\anaconda3\lib\site-packages (from matplotlib->koreanize-matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\11win\anaconda3\lib\site-packages (from matplotlib->koreanize-matplotlib) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\11win\anaconda3\lib\site-packages (from matplotlib->koreanize-matplotlib) (1.4.4)
# Requirement already satisfied: numpy>=1.20 in c:\users\11win\anaconda3\lib\site-packages (from matplotlib->koreanize-matplotlib) (1.24.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\11win\appdata\roaming\python\python311\site-packages (from matplotlib->koreanize-matplotlib) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\11win\anaconda3\lib\site-packages (from matplotlib->koreanize-matplotlib) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\11win\anaconda3\lib\site-packages (from matplotlib->koreanize-matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\11win\anaconda3\lib\site-packages (from matplotlib->koreanize-matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\11win\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->koreanize-matplotlib) (1.16.0)

# %% [markdown]
# 📌 Q1. 연령대별 허리둘레에 대한 기술통계를 구하려고 합니다. 다음 제공되는 딕셔너리를 통해 연령대코드(5세단위)를 "연령대"로 만들고 아래와 같은 기술통계값을 구해주세요!
#
# ![image.png](attachment:image.png)

# %%
#딕셔너리 생성
age_code = {
    1: '0~4세', 2: '5~9세', 3: '10~14세', 4: '15~19세', 5: '20~24세',
    6: '25~29세', 7: '30~34세', 8: '35~39세', 9: '40~44세', 10: '45~49세',
    11: '50~54세', 12: '55~59세', 13: '60~64세', 14: '65~69세', 15: '70~74세',
    16: '75~79세', 17: '80~84세', 18: '85세+'
}

# %%
df["연령대"] = df["연령대코드(5세단위)"].map(age_code)

# %%
age_waist_ratio = df.groupby("연령대")["허리둘레"].describe().reset_index()

# %%
print(age_waist_ratio)
# Out:
#        연령대     count       mean        std   min   25%   50%   75%    max
# 0   20~24세   23244.0  75.152220  12.251781  47.5  67.5  73.4  81.0  999.0
# 1   25~29세   64898.0  77.704783  16.735734  48.0  69.0  76.5  84.2  999.0
# 2   30~34세   77517.0  81.089268  22.988111  49.0  72.0  80.1  88.0  999.0
# 3   35~39세   84621.0  82.094012  14.522095   9.2  75.0  82.0  89.0  999.0
# 4   40~44세  130912.0  80.488308  10.803098  42.1  73.0  80.0  87.0  999.0
# 5   45~49세  118357.0  80.822449   9.521622  40.0  74.0  81.0  87.0  137.0
# 6   50~54세  129833.0  81.062754   9.095438   6.5  75.0  81.0  87.0  142.0
# 7   55~59세  112175.0  81.799905   8.730398  32.0  76.0  82.0  87.5  139.0
# 8   60~64세  106491.0  82.722769   8.596176   0.0  77.0  83.0  88.0  137.0
# 9   65~69세   53624.0  83.588500   8.443542  50.0  78.0  83.5  89.0  129.0
# 10  70~74세   51586.0  84.063372   8.539639  51.0  78.0  84.0  90.0  129.8
# 11  75~79세   25972.0  84.200127   8.772306  50.0  78.0  84.0  90.0  122.0
# 12  80~84세   16205.0  83.751435   9.041091  38.0  78.0  84.0  90.0  120.0
# 13    85세+    4125.0  81.736703  17.325969  34.0  75.0  81.5  88.0  999.0
